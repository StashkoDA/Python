# %% [markdown]
# <a href="https://colab.research.google.com/github/StashkoDA/Python/blob/main/sem10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')

# %% [markdown]
# **Задача №63.** Решение в группах
# 1. Изобразите отношение **households к population** с
# помощью точечного графика
# 2. Визуализировать **longitude** по отношению к
# **median_house_value**, используя линейный график
# 3. Представить гистограмму по **housing_median_age**
# 4. Изобразить гистограмму по **median_house_value** с
# оттенком **housing_median_age**

# %% [markdown]
# ***1. отношение households к population с помощью точечного графика:***

# %%
sns.scatterplot(data=df, x = 'population', y = 'households')
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %% [markdown]
# ***2. Визуализация longitude по отношению к
# median_house_value, используя линейный график:***

# %%
sns.relplot(x = 'median_house_value', y = 'longitude', kind = 'line', data = df)

# %% [markdown]
# ***3. Представить гистограмму по housing_median_age***

# %%
sns.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# ***4. Гистограмма по median_house_value с
# оттенком housing_median_age:***
#
# *from seaborn.widgets import plt
# plt.figure(figsize = (20, 10))* - это изменение размера окна гистограммы.

# %%
from seaborn.widgets import plt
plt.figure(figsize = (20, 10))
sns.histplot(data = df, x = 'median_house_value', hue = 'housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# **Задача №65.** Решение в группах
# Написать EDA для датасета про пингвинов
# Необходимо:
#
# ● Использовать 2-3 точечных графика
#
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
#
# ● Использовать PairGrid с типом графика на ваш выбор
#
# ● Изобразить Heatmap
#
# ● Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:
# penguins = sns.load_dataset("penguins")
# penguins.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(data = penguins, x = 'island', y = 'flipper_length_mm', hue = 'sex')
# Out:
# <Axes: xlabel='island', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data = penguins, x = 'island', y = 'bill_depth_mm', size = 'sex')
# Out:
# <Axes: xlabel='island', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data = penguins, x = 'island', y = 'bill_length_mm', stile = 'body_mass_g')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7f8295a6d3f8> in <cell line: 1>()
# ----> 1 sns.scatterplot(data = penguins, x = 'island', y = 'bill_length_mm', stile = 'body_mass_g')
#
# /usr/local/lib/python3.9/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     757     # and we should probably do that here too
#     758     color = kwargs.pop("color", None)
# --> 759     kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     760
#     761     p.plot(ax, kwargs)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/utils.py in _default_color(method, hue, color, kws)
#     120         scout_x = scout_y = np.full(scout_size, np.nan)
#     121
# --> 122         scout = method(scout_x, scout_y, **kws)
# ...

# %%
from seaborn.relational import scatterplot
cols = ['body_mass_g',	'bill_length_mm',	'bill_depth_mm',	'flipper_length_mm']
g = sns.PairGrid(penguins[cols])
g.map(sns.scatterplot)

# %% [markdown]
# **Изобразить Heatmap:**
#
# corr() - кореляция, соотношения

# %%
sns.heatmap(penguins.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
sns.histplot(data = penguins, x = 'island', hue = 'body_mass_g')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %%
plt.figure(figsize = (10, 5))
sns.histplot(data = penguins, x = 'island', hue = 'sex')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %% [markdown]
# **Задача №67.**
# Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# - high - длинный(от 42)
# - middle - средний(от 35 до 42)
# - low - маленький(до 35)
#
# Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:
#
# penguins = sns.load_dataset("penguins")
#
# penguins.head()

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.loc[penguins['bill_length_mm'] < 35, 'type_bill'] = 'low - маленький'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'type_bill'] = 'middle - средний'
penguins.loc[penguins['bill_length_mm'] > 42, 'type_bill'] = 'high - длинный'

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex         type_bill
# 0       3750.0    Male  middle - средний
# 1       3800.0  Female  middle - средний
# 2       3250.0  Female  middle - средний
# 3          NaN     NaN               NaN
# 4       3450.0  Female  middle - средний

# %% [markdown]
# Изобразить гистограмму по flipper_length_mm
# с оттенком type_bill. Сделать анализ

# %%
plt.figure(figsize = (25, 10))
sns.histplot(data = penguins, x = 'flipper_length_mm', hue = 'type_bill')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', hue = 'type_bill')

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', hue = 'type_bill', kind = 'kde')
